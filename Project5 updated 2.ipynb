# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# read in the csv file
bb = pd.read_csv('../project-05/LoanStats3d.csv', \
         keep_default_na = False, skiprows=1, usecols=['int_rate', \
        'dti', 'annual_inc', 'home_ownership', 'funded_amnt', 'term', 'loan_status'])

bb.columns
# Out:
# /Users/Misha/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3,13,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index([u'funded_amnt', u'term', u'int_rate', u'home_ownership', u'annual_inc',
#        u'loan_status', u'dti'],
#       dtype='object')

# %%
bb.head(10)
# Out:
#   funded_amnt        term int_rate home_ownership annual_inc loan_status  \
# 0       35000   60 months   14.85%       MORTGAGE     110000     Current
# 1       10400   60 months   22.45%       MORTGAGE     104433  Fully Paid
# 2       20000   60 months   10.78%       MORTGAGE      63000     Current
# 3       25000   36 months    7.49%       MORTGAGE     109000  Fully Paid
# 4       28000   36 months    6.49%       MORTGAGE      92000     Current
# 5       18000   60 months   11.99%       MORTGAGE     112000  Fully Paid
# 6       16000   60 months   14.85%       MORTGAGE      48000     Current
# 7       23000   60 months    8.49%           RENT      64000     Current
# 8        8650   36 months   19.89%           RENT      55000  Fully Paid
# 9        9600   36 months    7.49%       MORTGAGE      60000     Current
#
#      dti
# 0  17.06
# 1  25.37
# 2  10.78
# 3  26.02
# 4   21.6
# 5   8.68
# 6  33.18
# 7  18.28
# 8  25.49
# 9  22.44

# %%
print set(bb.loan_status)
print set(bb.home_ownership)
# Out:
# set(['', 'Late (31-120 days)', 'Default', 'Fully Paid', 'Current', 'Late (16-30 days)', 'Charged Off', 'In Grace Period'])
# set(['', 'OWN', 'RENT', 'MORTGAGE', 'ANY'])

# %%
# remove blank rows
bb[bb['loan_status'] == '']
bb[bb['funded_amnt'] == '']
bb[bb['int_rate'] == '']
bb[bb['home_ownership'] == '']
bb[bb['annual_inc'] == '']
bb[bb['dti'] == '']
# Out:
#        funded_amnt term int_rate home_ownership annual_inc loan_status dti
# 421095
# 421096

# %%
# Convert blanks to NaN's 

bb['loan_status'].replace('', np.nan, inplace=True)

# %%
bb.isnull().sum()
# Out:
# funded_amnt       0
# term              0
# int_rate          0
# home_ownership    0
# annual_inc        0
# loan_status       2
# dti               0
# dtype: int64

# %%
# Drop NA's.

bb = bb.dropna()
bb.isnull().sum()
# Out:
# funded_amnt       0
# term              0
# int_rate          0
# home_ownership    0
# annual_inc        0
# loan_status       0
# dti               0
# dtype: int64

# %%
len(bb[bb['loan_status'] == 'Current'])
# Out:
# 303912

# %%
# set the non-current loans to equal bb
bb = bb[bb['loan_status'] != 'Current']
bb.head(1)
# Out:
#   funded_amnt        term int_rate home_ownership annual_inc loan_status  \
# 1       10400   60 months   22.45%       MORTGAGE     104433  Fully Paid
#
#      dti
# 1  25.37

# %%
# Random sampling of 1000 data points

bb = bb.take(np.random.permutation(len(bb))[:1000])

# %%
# create column target by initilizing the column to all 0's, than set the loan
# statuses of the column into two different categories. Than count how many of each.
bb['target'] = [0]*len(bb)
bb['target'][bb['loan_status'] == 'In Grace Period'] = 1
bb['target'][bb['loan_status'] == 'Fully Paid'] = 1

del bb['loan_status']

bb['target'].value_counts()
# Out:
# /Users/Misha/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Misha/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 1    681
# 0    319
# Name: target, dtype: int64

# %%
bb.head(1)
# Out:
#       funded_amnt        term int_rate home_ownership annual_inc    dti  \
# 58571       28000   36 months   13.18%       MORTGAGE     100000  14.09
#
#        target
# 58571       1

# %%
bb = bb.reset_index(drop = True)
bad = np.where(bb['target'] == 0)[0]
good = np.where(bb['target'] == 1)[0]

# %%
# Remove % sign for interest rate
bb.int_rate = [float(x[:-1]) if (type(x) == str) else x for x in bb['int_rate']]

# %%
# Remove non-numeric characters from term column
bb.term = [int(x[:-6]) if (type(x) == str) else x for x in bb['term']]

# %%
bb.dtypes
# Out:
# funded_amnt        object
# term                int64
# int_rate          float64
# home_ownership     object
# annual_inc         object
# dti                object
# target              int64
# dtype: object

# %%
# convert column to integers
bb.funded_amnt = [int(x) if (type(x) == str) else x for x in bb['funded_amnt']]

# %%
# convert column to floats
bb.annual_inc  = [float(x) if (type(x) == str) else x for x in bb['annual_inc']]

# %%
# covert to float
bb.dti = [float(x) if (type(x) == str) else x for x in bb['dti']]

# %%
# Get dummies for Term

term = pd.get_dummies(bb.term)

term.columns = ["36 months", "60 months"]

# %%
# Add new term columns to table dataset.

bb = pd.concat([bb, term], axis = 1)

del bb["term"]
del bb['36 months']

# %%
# Create dummy variable for every category under home ownership

dumb_home = pd.get_dummies(bb.home_ownership)

dumb_home.head(2)
# Out:
#    MORTGAGE  OWN  RENT
# 0         1    0     0
# 1         0    0     1

# %%
# Add newly created dummy variable columns to dataset.

bb = pd.concat([bb, dumb_home], axis = 1)

del bb['home_ownership']
del bb['MORTGAGE']

# %%
bb.head(1)
# Out:
#    funded_amnt  int_rate  annual_inc    dti  target  60 months  OWN  RENT
# 0        28000     13.18    100000.0  14.09       1          0    0     0

# %%
bb.dtypes
# Out:
# funded_amnt      int64
# int_rate       float64
# annual_inc     float64
# dti            float64
# target           int64
# 60 months        uint8
# OWN              uint8
# RENT             uint8
# dtype: object

# %%
sns.pairplot(bb)

# %%
bb.funded_amnt.hist()

# %%
bb.int_rate.hist()

# %%
bb.head(10)
# Out:
#    funded_amnt  int_rate  annual_inc    dti  target  60 months  OWN  RENT
# 0        28000     13.18    100000.0  14.09       1          0    0     0
# 1         5000      8.18     65000.0  17.56       1          0    0     1
# 2        28000      5.93    136000.0  10.80       1          0    0     0
# 3         5000     11.53     23592.0  30.32       1          0    1     0
# 4        24000      8.18    120000.0  29.62       1          0    0     0
# 5         8000      9.99     50000.0  12.82       1          0    0     1
# 6        20000     18.84     60000.0  16.00       1          1    0     0
# 7        22000      9.99     52000.0  26.86       1          0    0     1
# 8         2000     17.86     37440.0   6.83       1          0    0     1
# 9        17500     12.05    125000.0  18.17       1          1    0     0

# %%
#Normalizing numerical variables

from sklearn.preprocessing import MinMaxScaler
y = pd.DataFrame(bb['target'], columns = ['target'])
X = bb.drop(['target'], axis = 1)
X_scaled = MinMaxScaler().fit_transform(X.astype(float))
X_scaled = pd.DataFrame(X_scaled, columns = X.columns)

# %%
#X_scaled.head()

# %%
min_val = float(bb['funded_amnt'].min())
max_val = float(bb['funded_amnt'].max())

def min_max(x):
    return (x-min_val)/(max_val-min_val)
bb['funded_amnt_standardized'] = bb['funded_amnt'].apply(lambda x: min_max(x))
bb

minimum_int_rate = float(bb['int_rate'].min())
maximum_int_rate = float(bb['int_rate'].max())

def min_max(x):
    return (x-minimum_int_rate)/(maximum_int_rate-minimum_int_rate)
bb['intest_rate_standardized'] = bb['int_rate'].apply(lambda x: min_max(x))
bb


minimum_annual_inc = float(bb['annual_inc'].min())
maximum_annual_inc = float(bb['annual_inc'].max())

def min_max(x):
    return (x-minimum_annual_inc)/(maximum_annual_inc-minimum_annual_inc)
bb['annual_inc_standardized'] = bb['annual_inc'].apply(lambda x: min_max(x))
bb

minimum_dti = float(bb['dti'].min())
maximum_dti = float(bb['dti'].max())

def min_max(x):
    return (x-minimum_dti)/(maximum_dti-minimum_dti)
bb['dti_standardized'] = bb['dti'].apply(lambda x: min_max(x))
bb
# Out:
#      funded_amnt  int_rate  annual_inc    dti  target  60 months  OWN  RENT  \
# 0          28000     13.18    100000.0  14.09       1          0    0     0
# 1           5000      8.18     65000.0  17.56       1          0    0     1
# 2          28000      5.93    136000.0  10.80       1          0    0     0
# 3           5000     11.53     23592.0  30.32       1          0    1     0
# 4          24000      8.18    120000.0  29.62       1          0    0     0
# 5           8000      9.99     50000.0  12.82       1          0    0     1
# 6          20000     18.84     60000.0  16.00       1          1    0     0
# 7          22000      9.99     52000.0  26.86       1          0    0     1
# 8           2000     17.86     37440.0   6.83       1          0    0     1
# 9          17500     12.05    125000.0  18.17       1          1    0     0
# 10         22000      9.99    147000.0  12.02       1          0    0     0
# 11          8000      6.92     45000.0   1.97       1          0    0     1
# 12         25000      5.93    125000.0  14.51       1          0    0     0
# 13         14000      5.93     89000.0  20.39       1          0    0     0
# 14          9600     15.59     38000.0  25.85       1          0    0     1
# 15         28975     24.99     63000.0  12.17       1          1    0     0
# 16         16000      9.49     49470.0   9.68       1          0    1     0
# 17          7000     14.65     40000.0  18.33       0          0    0     1
# 18         20000     13.99     47700.0  33.23       0          0    0     0
# 19         28000      9.99     81989.0  15.65       1          1    0     1
# 20         25000      6.49    115000.0   8.16       1          0    0     0
# 21         20000     12.39     95000.0  12.71       1          0    0     0
# 22         12225     15.59     60000.0  23.42       1          0    0     0
# 23          4000      8.18     49000.0  10.74       1          0    0     0
# 24         11000     11.99     58000.0  16.84       1          1    0     0
# 25         15000      6.92     78000.0   7.23       1          0    0     0
# 26         10000      7.89    103000.0   7.58       0          1    0     1
# 27          4950     17.86     75000.0  14.45       1          0    0     1
# 28         25000     12.69     91345.0  23.12       0          0    0     0
# 29         10000     18.25     28500.0  27.24       1          1    0     1
# ..           ...       ...         ...    ...     ...        ...  ...   ...
# 970         5000     10.99    116000.0  10.45       1          0    0     0
# 971         5000     12.99     38964.0   6.41       1          0    0     0
# 972         6450     16.99     33000.0  19.93       0          0    0     1
# 973         8000      9.17     60000.0   8.62       1          0    0     1
# 974        20000     12.69     85000.0  25.59       1          0    0     0
# 975        20000     16.55    100000.0  11.93       1          1    0     1
# 976         8000     15.59     31000.0  13.16       1          0    0     0
# 977        24350     12.69     53000.0  29.60       1          1    0     1
# 978        11000      6.89     55000.0   5.19       1          0    0     1
# 979        10325     17.86     24600.0  20.07       0          1    0     1
# 980         5000     16.55     67000.0  10.84       0          0    0     0
# 981        15000     18.55     53000.0  32.84       0          1    1     0
# 982        20000     13.99     60000.0  28.61       1          0    0     1
# 983         5000      6.99     59900.0   9.56       1          0    0     1
# 984        12000     11.53     75000.0  26.59       1          0    0     0
# 985         7350     14.31     26000.0  17.91       1          0    1     0
# 986        24000      6.24    126000.0  19.52       1          0    0     0
# 987        10000     15.59     34000.0  17.23       1          0    0     0
# 988        15000      7.89    359000.0  12.00       1          0    0     0
# 989         8000     10.64     46000.0  34.88       0          0    1     0
# 990        20000     11.49     80000.0  31.14       0          0    0     0
# 991         5000     12.69     40000.0  13.17       1          0    0     1
# 992         3000     11.53    110000.0   9.52       1          0    0     0
# 993         8400      7.89     35000.0  12.48       1          0    0     1
# 994        21000      6.92     43000.0  25.15       1          0    0     1
# 995        11100     14.65     72000.0  13.05       1          0    0     0
# 996        14400     13.33    150000.0  12.10       1          1    0     0
# 997        12000     12.29     77000.0  16.11       1          1    0     0
# 998        14400      9.80    200000.0  26.38       0          0    0     0
# 999        11500      9.17     49000.0  17.32       1          0    0     1
#
#      funded_amnt_standardized  intest_rate_standardized  \
# 0                    0.794118                  0.348404
# 1                    0.117647                  0.126773
# 2                    0.794118                  0.027039
# 3                    0.117647                  0.275266
# 4                    0.676471                  0.126773
# 5                    0.205882                  0.207004
# 6                    0.558824                  0.599291
# 7                    0.617647                  0.207004
# 8                    0.029412                  0.555851
# 9                    0.485294                  0.298316
# 10                   0.617647                  0.207004
# 11                   0.205882                  0.070922
# 12                   0.705882                  0.027039
# 13                   0.382353                  0.027039
# 14                   0.252941                  0.455230
# 15                   0.822794                  0.871897
# 16                   0.441176                  0.184840
# 17                   0.176471                  0.413564
# 18                   0.558824                  0.384309
# 19                   0.794118                  0.207004
# 20                   0.705882                  0.051862
# 21                   0.558824                  0.313387
# 22                   0.330147                  0.455230
# 23                   0.088235                  0.126773
# 24                   0.294118                  0.295656
# 25                   0.411765                  0.070922
# 26                   0.264706                  0.113918
# 27                   0.116176                  0.555851
# 28                   0.705882                  0.326684
# 29                   0.264706                  0.573138
# ..                        ...                       ...
# 970                  0.117647                  0.251330
# 971                  0.117647                  0.339982
# 972                  0.160294                  0.517287
# 973                  0.205882                  0.170656
# 974                  0.558824                  0.326684
# 975                  0.558824                  0.497784
# 976                  0.205882                  0.455230
# 977                  0.686765                  0.326684
# 978                  0.294118                  0.069592
# 979                  0.274265                  0.555851
# 980                  0.117647                  0.497784
# 981                  0.411765                  0.586436
# 982                  0.558824                  0.384309
# 983                  0.117647                  0.074025
# 984                  0.323529                  0.275266
# 985                  0.186765                  0.398493
# 986                  0.676471                  0.040780
# 987                  0.264706                  0.455230
# 988                  0.411765                  0.113918
# 989                  0.205882                  0.235816
# 990                  0.558824                  0.273493
# 991                  0.117647                  0.326684
# 992                  0.058824                  0.275266
# 993                  0.217647                  0.113918
# 994                  0.588235                  0.070922
# 995                  0.297059                  0.413564
# 996                  0.394118                  0.355053
# 997                  0.323529                  0.308954
# 998                  0.394118                  0.198582
# 999                  0.308824                  0.170656
#
#      annual_inc_standardized  dti_standardized
# 0                   0.121715          0.349066
# 1                   0.073306          0.436648
# 2                   0.171508          0.266027
# 3                   0.016033          0.758708
# 4                   0.149378          0.741040
# 5                   0.052559          0.317012
# 6                   0.066390          0.397274
# 7                   0.055325          0.671378
# 8                   0.035187          0.165825
# 9                   0.156293          0.452044
# 10                  0.186722          0.296820
# 11                  0.045643          0.043160
# 12                  0.156293          0.359667
# 13                  0.106501          0.508077
# 14                  0.035961          0.645886
# 15                  0.070539          0.300606
# 16                  0.051826          0.237759
# 17                  0.038728          0.456083
# 18                  0.049378          0.832155
# 19                  0.096804          0.388440
# 20                  0.142462          0.199394
# 21                  0.114799          0.314235
# 22                  0.066390          0.584553
# 23                  0.051176          0.264513
# 24                  0.063624          0.418476
# 25                  0.091286          0.175921
# 26                  0.125864          0.184755
# 27                  0.087137          0.358152
# 28                  0.109744          0.576981
# 29                  0.022822          0.680969
# ..                       ...               ...
# 970                 0.143845          0.257193
# 971                 0.037295          0.155225
# 972                 0.029046          0.496466
# 973                 0.066390          0.211005
# 974                 0.100968          0.639324
# 975                 0.121715          0.294548
# 976                 0.026279          0.325593
# 977                 0.056708          0.740535
# 978                 0.059474          0.124432
# 979                 0.017427          0.500000
# 980                 0.076072          0.267037
# 981                 0.056708          0.822312
# 982                 0.066390          0.715548
# 983                 0.066252          0.234730
# 984                 0.087137          0.664563
# 985                 0.019364          0.445482
# 986                 0.157676          0.486118
# 987                 0.030429          0.428319
# 988                 0.479945          0.296315
# 989                 0.047026          0.873801
# 990                 0.094053          0.779404
# 991                 0.038728          0.325846
# 992                 0.135546          0.233720
# 993                 0.031812          0.308430
# 994                 0.042877          0.628218
# 995                 0.082988          0.322817
# 996                 0.190871          0.298839
# 997                 0.089903          0.400050
# 998                 0.260028          0.659263
# 999                 0.051176          0.430591
#
# [1000 rows x 12 columns]

# %%
del bb['funded_amnt']
del bb['int_rate']  
del bb['annual_inc']
del bb['dti']

# %%
# plot of Interest Rate vs DTI
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(X_scaled.int_rate[good], X_scaled.dti[good], alpha=0.5, color='g')
ax.scatter(X_scaled.int_rate[bad], X_scaled.dti[bad], alpha=0.5, color='r')
ax.set_title("Interest Rate vs DTI")
ax.set_xlabel("int_rate")
ax.set_ylabel("dti")
plt.show()

# %%
print bb.to_csv('bb.csv',header=None,index=False)

bb_clean_noheaders = pd.read_csv('bb.csv', header=None)

bb_clean_noheaders.head(10)
# Out:
# None
#    0  1  2  3         4         5         6         7
# 0  1  0  0  0  0.794118  0.348404  0.121715  0.349066
# 1  1  0  0  1  0.117647  0.126773  0.073306  0.436648
# 2  1  0  0  0  0.794118  0.027039  0.171508  0.266027
# 3  1  0  1  0  0.117647  0.275266  0.016033  0.758708
# 4  1  0  0  0  0.676471  0.126773  0.149378  0.741040
# 5  1  0  0  1  0.205882  0.207004  0.052559  0.317012
# 6  1  1  0  0  0.558824  0.599291  0.066390  0.397274
# 7  1  0  0  1  0.617647  0.207004  0.055325  0.671378
# 8  1  0  0  1  0.029412  0.555851  0.035187  0.165825
# 9  1  1  0  0  0.485294  0.298316  0.156293  0.452044

# %%
sig = lambda x: 1./(1+np.exp(-x))
def lnpred(data, a):
    pairedsum = a[0] + a[1]*data[1] + a[2]*data[2]+ a[3]*data[3] + a[4]*data[4] + a[5]*data[5] \
    + a[6]*data[6] + a[7]*data[7]
    if data[0] == 1:
        return np.log(sig(pairedsum))
    else:
        return np.log(1-sig(pairedsum))

# %%
def lnprob(a,data):
    A2 = np.sum([e**2 for e in a])
    return -0.5*A2 + np.sum([lnpred(e,a) for e in data])

# %%
blah = lambda a: lnprob(a, bb.values)

# %%
import emcee
nwalkers = 20
ndim = 8
p0 = np.random.rand(nwalkers*ndim).reshape((nwalkers,ndim))
sampler = emcee.EnsembleSampler(nwalkers, ndim, blah)
pos, prob, state = sampler.run_mcmc(p0, 1000)
sampler.reset()
pos, prob, state = sampler.run_mcmc(pos, 10000)
samples = sampler.flatchain

# %%
def MonteCarlo(f, samples):
    N = len(samples)
    return 1/float(N)*sum([f(e) for e in samples])

# %%
sigmoid = lambda g: 1./(1+np.exp(-g))

def predictive(w):  
    g = w[0] + w[1]*bb.ix[0][0] + w[2]*bb.ix[0][1] + w[3]*bb.ix[0][2] + w[4]*bb.ix[0][3]\
       + w[5]*bb.ix[0][4] + w[6]*bb.ix[0][5] + w[7]*bb.ix[0][6]
    return sigmoid(g)

# %%
MonteCarlo(predictive, samples)
# Out:
# 0.59044215779098341
