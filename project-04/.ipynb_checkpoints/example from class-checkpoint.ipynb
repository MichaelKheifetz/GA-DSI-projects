# %%
import numpy as np
import matplotlib as np1
import seaborn as sns
# %matplotlib inline
z = np.random.normal(0,1,size=(100000,))
sns.distplot(z)

# %%
x1 = 2 + 3*z
sns.distplot(x1)




def E(func, samples):
    N = len(samples)
    return 1./N*np.sum([func(e) for e in samples])

# %%
def E(fund, samples):
    N= len(samples)
    return 1./N*np.sum
